# %% [markdown]
# ### Создаем алгоритм машинного обучения
#
# для каждого критерия определенный **коэффициент значимости** или, как часто говорят, **вес**.
#
# Например, уровню дохода задать вес 0,2, а стажу — 0,35.

# %% [markdown]
# ### Строим уравнение
#
# w = [0.32, 0.55]  **вектор весов** (условные коэффициент значимости)
#
# x = [7, 100000]  вектор данных
#
# y = w1x1 + w2x2+...wnxn => ЭТО СКАЛЯРНОРНОЕ ПРОИЗВДЕНИЕ ВЕКТОРОВ

# %% [markdown]
# ### Ищем веса
# Есть специальный алгоритм - алгоритм оптимизации, который подберет нам такие веса.
#
# На практике веса до оптимизации берутся случайно, после оптимизации находятся в процессе обучения модели.

# %% [markdown]
# ### Какие шаги нужно выполнить для обучения модели:
#
# Выделяем важные для нас критерии (возраст, стаж и т.д.)
#
# Составляем уравнение с этими критериями и пока еще неизвестными весами
#
# Берем имеющися исторические данные
#
# Запускаем алгоритм оптимизации и ищем веса, которые максимально «укладываются» в наши данные
#
# Подставляем веса в модель
#
# На все тех же имеющихся данных проверяем качество модели
#
# Используем модель в работе с новыми данными

# %% [markdown]
# ### Вопросы для закрепления

# %% [markdown]
# Какие данные используются для обучения модели, новые или уже имеющиеся?

# %% [markdown]
# ответ:

# %% [markdown]
# Как называется процесс подбора весов уравнения (модели)?

# %% [markdown]
# ответ:

# %% [markdown]
# Какие данные используются для предсказания, новые или уже имющиеся?

# %% [markdown]
# ответ:
